# %% [markdown]
# Step 1: Import packages and classes

# %%
#importing all the necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/Salary_Data1.csv")

# %%
data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
data.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
data.shape
# Out:
# (30, 2)

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %% [markdown]
# **Missing value detection in the data**

# %% [markdown]
# The following values in the dataset are considered to be the missing values.
#
# 1.Blank values
#
# 2.Nan
#
# 3.null
#
# 4.some continous columns might have 0's to indicate missing data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.plot(data["Salary"],data ["YearsExperience"])

# %%
data
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %% [markdown]
# Lets plot a co relation plot . this will help us to understand if thereis multi colinearity in the data set

# %%
f,ax = plt.subplots(figsize=(7,4))
corr = data.corr('pearson')
plt.title("Correlation of Features")
sns.heatmap(corr,annot=True)
# Out:
# <Axes: title={'center': 'Correlation of Features'}>

# %%
from sklearn.model_selection import train_test_split

# %%
x=data.drop("Salary",axis = 1)

# %%
y = data['Salary'])

# %%
print(x.head())

print(y.head())
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# Name: Salary, dtype: int64

# %%
xtrain,xtest ,ytrain,ytest = train_test_split(x,y,test_size = 0.2, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
L = LinearRegression()

# %%
L.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_pred = L.predict(xtest)

# %%
print(L.score(xtest,ytest))
# Out:
# 0.9024461774180497

# %%
print('actual salary',y)
print("predicted salary",y_pred)
# Out:
# actual salary 0      39343
# 1      46205
# 2      37731
# 3      43525
# 4      39891
# 5      56642
# 6      60150
# 7      54445
# 8      64445
# 9      57189
# 10     63218
# 11     55794
# 12     56957
# 13     57081
# 14     61111
# 15     67938
# 16     66029
# 17     83088
# 18     81363
# 19     93940
# 20     91738
# 21     98273
# 22    101302
# 23    113812
# 24    109431
# 25    105582
# 26    116969
# 27    112635
# 28    122391
# 29    121872
# Name: Salary, dtype: int64
# predicted salary [115790.21011287  71498.27809463 102596.86866063  75267.80422384
#   55477.79204548  60189.69970699]
